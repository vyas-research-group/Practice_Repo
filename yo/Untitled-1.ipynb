# %%
import pandas as pd

data = pd.read_excel(r"C:\Users\steve\OneDrive\Documents\Vyas Research\Polyenes\NBO_Graph.xlsx")

# %%
fig = plt.figure()
x = np.arange(2,10,2)
for k in range(data.shape[1]):
    points = data.iloc[:,k]
    plt.plot(x, points)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 fig = plt.figure()
#       2 x = np.arange(2,10,2)
#       3 for k in range(data.shape[1]):
#
# NameError: name 'plt' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Function to fit the curve
def curve_function(x, A, B, C):
    return A * np.log(B * x) + C

# Load Excel spreadsheet
df = pd.read_excel(r"C:\Users\steve\OneDrive\Documents\Vyas Research\Polyenes\NBO_Graph.xlsx")

# Define x and y data
x_data = np.arange(2,10,2)

# Select rows 2 to 5 for y_data
for k in range(5):
    y_data = df.iloc[1:5, k]  # Select rows 2 to 5
    plt.plot(x_data, y_data, label=f'Column {k}')

plt.xlabel('Carbon Chain Length')
plt.xticks(np.arange(min(x_data), max(x_data)+1, 1))
plt.ylabel('Resonance Stabalization Energy (kcal/mol)')
plt.legend(df.iloc[0:k])


print(x_data)
# Out:
# [2 4 6 8]

# %% [markdown]
# $RSE = H_{TS}-H_{aligned}$
